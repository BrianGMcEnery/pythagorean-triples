# %% [markdown]
# ## This is an Experimental Notebook

# %% [markdown]
# This is an experiment to develop the ability to draw geometrical items.

# %%
from geom2d import Drawing
from geom2d import Point
from geom2d import LineSegment
from geom2d import Triangle

# %%
drawing = Drawing()
p = Point(1,1)
print(p)
# Out:
# Point(1, 1)

# %%
drawing.add(p)
drawing.draw()

# %%
l = LineSegment(Point(0, 0), Point(1,2))
print(l)
# Out:
# LineSegment(Point(0, 0), Point(1, 2))

# %%
drawing.add(l)
drawing.draw()

# %%
t = Triangle(Point(0,0), Point(3,0), Point(3,4))
print(t)
# Out:
# Triangle(Point(0, 0), Point(3, 0), Point(3, 4))

# %%
drawing.add(t)
drawing.draw()

# %% [markdown]
# Got it!
